# %% [markdown]
# ## PC-wise full candidates votes lists over time

# %%
import pandas as pd
import os

# %%
pcfile = '2024-PC-attributes.csv'
folder1 = 'state_wise_results'
folder2 = 'pc_wise_results'

# %%
df1 = pd.read_csv(pcfile, dtype=str).fillna('')

# %%
df1.sample(5)
# Out:
#     OBJECTID pc_id s_u st_code        st_name pc_no            pc_name  \
# 306      336   818   S      20      RAJASTHAN    18             Jalore
# 81        82  1040   S       4          BIHAR    40         Jamui (SC)
# 361      409   906   S      24  UTTAR PRADESH     6          Moradabad
# 241      215  2741   S      13    MAHARASHTRA    41              Latur
# 138      519  2915   S      10      KARNATAKA    15  Udupi Chikmagalur
#
#          pc_name_alias status State_LGD  ...      Phase DOP Poll_Day  \
# 306             Jalore                8  ...  2ND PHASE       Friday
# 81               Jamui               10  ...  1ST PHASE       Friday
# 361          Moradabad                9  ...  1ST PHASE       Friday
# 241              Latur               27  ...  3RD PHASE      Tuesday
# 138  Udupi Chikmagalur               29  ...  2ND PHASE       Friday
#
#                      DOA                  DOIN                  LDFN  \
# 306  16-3-2024(Saturday)   28-3-2024(Thursday)    4-4-2024(Thursday)
# 81   16-3-2024(Saturday)  20-3-2024(Wednesday)   28-3-2024(Thursday)
# 361  16-3-2024(Saturday)  20-3-2024(Wednesday)  27-3-2024(Wednesday)
# 241  16-3-2024(Saturday)    12-4-2024 (Friday)    19-4-2024 (Friday)
# 138  16-3-2024(Saturday)   28-3-2024(Thursday)    4-4-2024(Thursday)
#
#                       DSN                 LDWC               DOCV Date_of_Poll
# 306     05-4-2024(Friday)     08-4-2024(Monday  4-6-2024(Tuesday)    4/26/2024
# 81    30-3-2024(Saturday)    2-4-2024(Tuesday)  4-6-2024(Tuesday)    4/19/2024
# 361   28-3-2024(Thursday)  30-3-2024(Saturday)  4-6-2024(Tuesday)    4/19/2024
# 241  20-4-2024 (Saturday)    22-4-2024(Monday)  4-6-2024(Tuesday)     5/7/2024
# 138     05-4-2024(Friday)     08-4-2024(Monday  4-6-2024(Tuesday)    4/26/2024
#
# [5 rows x 23 columns]

# %%
pc_files = sorted(os.listdir(folder2)) # always sort!
pc_files[:2]
# Out:
# ['pc_results_2024-06-04 16:30:28.csv', 'pc_results_2024-06-04 16:31:44.csv']

# %%
collector = []
missing_s_u_count = 0

for file1 in pc_files:
    df2 = pd.read_csv(os.path.join(folder2, file1),dtype=str).fillna('')
    if 'timestamp' not in df2.columns:
        print(f"Discarding {file1} as timestamp missing")
        continue
    
    if 'source_url' not in df2.columns:
        print(f"{file1} missing source_url, skiping")
        continue
    
    # clean up pc_no
    df2['pc_no'] = df2['pc_no'].apply(lambda x: x.replace('.0',''))
    
    # missing s_u : detect from source_url
    if 's_u' not in df2.columns:
        missing_s_u_count += 1
        df2['s_u'] = df2['source_url'].str.replace('https://results.eci.gov.in/PcResultGenJune2024/Constituencywise','').str[0]
    
    
    # add filename
    df2['source_file'] = file1
    
    # state_name and pc_name was wrongly recorded of UTs in some cases. need to replace from lookup
    if 'st_name' in df2.columns:
        df2.drop(columns=['st_name'], inplace=True)
    
    if 'pc_name' in df2.columns:
        df2.drop(columns=['pc_name'], inplace=True)
    
    collector.append(df2)
# Out:
# Discarding pc_results_2024-06-04 16:30:28.csv as timestamp missing

# %%
df3 = pd.concat(collector, ignore_index=True, sort=False).sort_values('timestamp').reset_index(drop=True)

# %%
# bringing in state and pc names
lookup_cols = ['s_u','st_code','st_name','pc_no','pc_name_alias']
df4 = pd.merge(df3, df1[lookup_cols], how='left', on=['s_u','st_code','pc_no']).rename(columns={'pc_name_alias':'pc_name'})
# rename 'pc_name_alias

# %%
df4.sample(10)
# Out:
#         st_code pc_no               candidate_name  \
# 597278       10    17                 DURGA PRASAD
# 1897829      11    18                P KRISHNAMMAL
# 3312267      22    37                     A SEETHA
# 4198032      25    41             SHYAMALI PRADHAN
# 3454859      22    18                   PALANI, V.
# 2125349      24    70                  GOPAL SINGH
# 4128504       2     1                   NABAM TUKI
# 1124537       4     6            ASHOK KUMAR YADAV
# 116988        6    15  UMESHBHAI NARANBHAI MAKWANA
# 750112       22     7               A JAYACHANDRAN
#
#                                              party evm_votes postal_votes  \
# 597278                     Karunada Sevakara Party      2578           14
# 1897829  Marxist Communist Party of India (United)       537           12
# 3312267                      Bahujan Dravida Party      2476            -
# 4198032        Communist Party of India  (Marxist)     98819          564
# 3454859                        Bahujan Samaj Party      6013           41
# 2125349                          Azad Adhikar Sena       729            8
# 4128504                   Indian National Congress    100100         4579
# 1124537                     Bharatiya Janata Party    552705          723
# 116988                             Aam Aadmi Party    256902         4692
# 750112                                 Independent       534            -
#
#         total_votes vote_percentage  \
# 597278         2592            0.18
# 1897829         549            0.06
# 3312267        2476            0.24
# 4198032       99383             6.5
# 3454859        6054            0.53
# 2125349         737            0.06
# 4128504      104679           26.18
# 1124537      553428           53.85
# 116988       261594           24.98
# 750112          534            0.05
#
#                                                 source_url  \
# 597278   https://results.eci.gov.in/PcResultGenJune2024...
# 1897829  https://results.eci.gov.in/PcResultGenJune2024...
# 3312267  https://results.eci.gov.in/PcResultGenJune2024...
# 4198032  https://results.eci.gov.in/PcResultGenJune2024...
# 3454859  https://results.eci.gov.in/PcResultGenJune2024...
# 2125349  https://results.eci.gov.in/PcResultGenJune2024...
# 4128504  https://results.eci.gov.in/PcResultGenJune2024...
# 1124537  https://results.eci.gov.in/PcResultGenJune2024...
# 116988   https://results.eci.gov.in/PcResultGenJune2024...
# 750112   https://results.eci.gov.in/PcResultGenJune2024...
#
#                    timestamp s_u                         source_file  \
# 597278   2024-06-04 20:29:25   S  pc_results_2024-06-04 20:28:08.csv
# 1897829  2024-06-05 00:07:55   S  pc_results_2024-06-05 00:07:28.csv
# 3312267  2024-06-05 04:19:33   S  pc_results_2024-06-05 04:18:47.csv
# 4198032  2024-06-05 06:57:19   S  pc_results_2024-06-05 06:56:03.csv
# 3454859  2024-06-05 04:45:13   S  pc_results_2024-06-05 04:44:24.csv
# 2125349  2024-06-05 00:49:26   S  pc_results_2024-06-05 00:48:22.csv
# 4128504  2024-06-05 06:45:25   S  pc_results_2024-06-05 06:45:22.csv
# 1124537  2024-06-04 22:10:30   S  pc_results_2024-06-04 22:10:19.csv
# 116988   2024-06-04 18:03:17   S  pc_results_2024-06-04 18:01:36.csv
# 750112   2024-06-04 21:06:21   S  pc_results_2024-06-04 21:04:56.csv
#
#                    st_name           pc_name
# 597278           KARNATAKA  Dakshina Kannada
# 1897829             KERALA            Kollam
# 3312267         TAMIL NADU           Tenkasi
# 4198032        WEST BENGAL            Bolpur
# 3454859         TAMIL NADU          Tiruppur
# 2125349      UTTAR PRADESH             Ghosi
# 4128504  ARUNACHAL PRADESH    Arunachal West
# 1124537              BIHAR         Madhubani
# 116988             GUJARAT         Bhavnagar
# 750112          TAMIL NADU         Arakkonam

# %%
len(df4)
# Out:
# 4432191

# %%
df4.sample().T
# Out:
#                                                            3781414
# st_code                                                          7
# pc_no                                                            4
# candidate_name                                     ISHWAR JHAJHRIA
# party                                                  Independent
# evm_votes                                                     1121
# postal_votes                                                     1
# total_votes                                                   1122
# vote_percentage                                                0.1
# source_url       https://results.eci.gov.in/PcResultGenJune2024...
# timestamp                                      2024-06-05 05:43:35
# s_u                                                              S
# source_file                     pc_results_2024-06-05 05:43:17.csv
# st_name                                                    HARYANA
# pc_name                                                      Hisar

# %%
df4.columns
# Out:
# Index(['st_code', 'pc_no', 'candidate_name', 'party', 'evm_votes',
#        'postal_votes', 'total_votes', 'vote_percentage', 'source_url',
#        'timestamp', 's_u', 'source_file', 'st_name', 'pc_name'],
#       dtype='object')

# %%
df5 = df4.drop_duplicates(['s_u', 'st_code', 'pc_no', 'candidate_name', 'evm_votes', 'postal_votes'])\
.sort_values(['s_u','st_code', 'pc_no', 'candidate_name', 'timestamp']).reset_index(drop=True)

# %%
len(df5)
# Out:
# 113859

# %%
print(f"After de-duplicating entries where there were no changes recorded, data reduced from {len(df4)} to {len(df5)} rows")
# Out:
# After de-duplicating entries where there were no changes recorded, data reduced from 4432191 to 113859 rows

# %%
df5.sample(2)
# Out:
#       st_code pc_no        candidate_name                party evm_votes  \
# 16909      13    18  VIKAS CHHAGAN LAHANE          Independent       609
# 62124      22    37       ESAI MATHIVANAN  Naam Tamilar Katchi    128685
#
#       postal_votes total_votes vote_percentage  \
# 16909            -         609            0.05
# 62124         1585      130270           12.54
#
#                                               source_url            timestamp  \
# 16909  https://results.eci.gov.in/PcResultGenJune2024...  2024-06-04 20:19:13
# 62124  https://results.eci.gov.in/PcResultGenJune2024...  2024-06-04 20:18:35
#
#       s_u                         source_file      st_name  pc_name
# 16909   S  pc_results_2024-06-04 20:17:39.csv  MAHARASHTRA    Jalna
# 62124   S  pc_results_2024-06-04 20:15:28.csv   TAMIL NADU  Tenkasi

# %%
columns_order = ['s_u', 'st_code', 'pc_no', 'st_name', 'pc_name', 'candidate_name', 'party',
       'evm_votes', 'postal_votes', 'total_votes', 'vote_percentage',
    'timestamp', 'source_url', 'source_file' ]

# %%
df5[columns_order].to_csv('Elections2024_candidates_votes_changes.csv', index=False)
